# %% [markdown]
# ## Calculate Betting Returns
# Using the bookie probabilities and our model probabilities we can calculate best value bets and track how profitable these bets would have been.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import log_loss
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn import ensemble, metrics, model_selection as ms, preprocessing, tree
from sklearn import linear_model as lm
import statsmodels.api as sm
import statsmodels.formula.api as smf
pd.set_option('display.max_columns', 50)
from sklearn.pipeline import Pipeline
from os import listdir
from os.path import isfile, join

# %%
data_folder = "C:/Users/Byron/Documents/Football Predictions/UnderstatPredictions/Datasets"

# %%
pred_df = pd.read_csv(data_folder+"/xg_predictions.csv")
pred_df.head()
# Out:
#        league   season                     fixture  season_gw      Team_Home  \
# 0  Bundesliga  2014/15  Bayern Munich vs Wolfsburg          1  Bayern Munich
# 1  Bundesliga  2014/15  Bayern Munich vs Wolfsburg          1  Bayern Munich
# 2  Bundesliga  2014/15  Bayern Munich vs Wolfsburg          1  Bayern Munich
# 3  Bundesliga  2014/15  Bayern Munich vs Wolfsburg          1  Bayern Munich
# 4  Bundesliga  2014/15      Hoffenheim vs Augsburg          1     Hoffenheim
#
#    Team_Away  homegoals  awaygoals Result                AverageMethod  \
# 0  Wolfsburg        2.0        1.0      H                 EMA No reset
# 1  Wolfsburg        2.0        1.0      H      Moving Average No reset
# 2  Wolfsburg        2.0        1.0      H             EMA Season reset
# 3  Wolfsburg        2.0        1.0      H  Moving Average Season reset
# 4   Augsburg        2.0        0.0      H                 EMA No reset
#
# ...

# %%
bookie_df =pd.read_csv(data_folder+"/bookie_odds.csv").drop(columns="Unnamed: 0")
bookie_df.head()
# Out:
#   league   season        Date                    fixture HomeTeam  \
# 0    EPL  2014/15    16/08/14  Arsenal vs Crystal Palace  Arsenal
# 1    EPL  2015/16    17/04/16  Arsenal vs Crystal Palace  Arsenal
# 2    EPL  2016/17    01/01/17  Arsenal vs Crystal Palace  Arsenal
# 3    EPL  2017/18  20/01/2018  Arsenal vs Crystal Palace  Arsenal
# 4    EPL  2018/19  21/04/2019  Arsenal vs Crystal Palace  Arsenal
#
#          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 0  Crystal Palace   2.0   1.0   H   1.0   1.0   D            1.25
# 1  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 2  Crystal Palace   2.0   0.0   H   1.0   0.0   H            1.29
# 3  Crystal Palace   4.0   1.0   H   4.0   0.0   H            1.50
# 4  Crystal Palace   2.0   3.0   A   0.0   1.0   A            1.53
#
#    BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 0            6.50            15.0  Bet365        0.800000        0.153846
# ...

# %%
pred_df = pred_df[["league","season","fixture","season_gw","Team_Home","Team_Away","Result","AverageMethod","HomeProb","DrawProb","AwayProb"
                 ,"PredResult","PredScore","PredScoreProb","PredResultScore","PredResultScoreProb","FinalScore"
                 ,"PredCorrect","PredResultScoreCorrect","PredScoreCorrect","FinalResultProb"]]
gambling_df = pd.merge(bookie_df,pred_df,on=["league","season","fixture"])
print(gambling_df.head(20))
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 0     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 1     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 2     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 3     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 4     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 5     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 6     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 7     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 8     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 9     EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 10    EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 11    EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# 12    EPL  2014/15  16/08/14  Arsenal vs Crystal Palace  Arsenal
# ...

# %% [markdown]
# # Gambling calculations
# We want to calculate the winnings for each result, and the expected winnings based on the model probabilities.
#
# The expected winnings is calculated as: <br>
# - Probability that we'll win the returns offered by the bookie - the probability that we'll lose our stake. <br>
# - eg. We calculate there is a 60% Team A will win. The bookie is offering odds of 1.5. This means for a £5 stake we will return £7.50, or make a profit £2.50
# - Using our own probabilities, we calculate there is also a 40% chance that we lose our £5 entirely.
# - (0.6 * 2.50) - (0.4 * 5) equates to  1.5 - 2 = - 0.5
# - Even though we think Team A is going to win, the odds offered by the bookie are not good enough for us to make a return on that bet in the long run

# %%
#define stake
stake = 5

def returns(stake,odds):
    returns = stake*odds-stake
    return returns

def expected_returns(stake,returns,prob):
    p = prob/100
    exp_returns = (returns*p)-((1-p)*stake)
    return exp_returns

def result_returns(row):
    #if np.isnan(row["PredResult"])==False:
    if row["Result"] == "H":
        return row["HomeReturns"]
    if row["Result"] == "D":
        return row["DrawReturns"]
    if row["Result"] == "A":
        return row["AwayReturns"]

gambling_df["Stake"] = stake
gambling_df["HomeReturns"]=gambling_df["BookieHomeOdds"].apply(lambda x: returns(stake,x))
gambling_df["DrawReturns"]=gambling_df["BookieDrawOdds"].apply(lambda x: returns(stake,x))
gambling_df["AwayReturns"]=gambling_df["BookieAwayOdds"].apply(lambda x: returns(stake,x))

gambling_df["ResultReturns"]= gambling_df.apply(lambda row: result_returns(row), axis =1)

gambling_df["ExpHomeReturns"] = gambling_df.apply(lambda row: expected_returns(row.Stake,row.HomeReturns,row.HomeProb)
                                                , axis = 1)
gambling_df["ExpDrawReturns"] = gambling_df.apply(lambda row: expected_returns(row.Stake,row.DrawReturns,row.DrawProb)
                                                , axis = 1)
gambling_df["ExpAwayReturns"] = gambling_df.apply(lambda row: expected_returns(row.Stake,row.AwayReturns,row.AwayProb)
                                                , axis = 1)
gambling_df[gambling_df["season_gw"]>2].head()
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 20    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 21    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 22    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 23    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 24    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
#
#           AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 20  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 21  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 22  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 23  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 24  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
#
#     BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 20            5.75            9.50  Bet365         0.75188        0.173913
# ...

# %% [markdown]
# We will now calculate the best value bets as determined by our model, and the hypothetical profit or losses they would have made

# %%
#def determine_bet()

gambling_df["BestValueExpReturns"]= gambling_df[["ExpHomeReturns","ExpDrawReturns","ExpAwayReturns"]].max(axis=1)


def determine_bet(row):
    #if np.isnan(row["PredResult"])==False:
    if row["BestValueExpReturns"] == row["ExpHomeReturns"]:
        return "H"
    if row["BestValueExpReturns"] == row["ExpDrawReturns"]:
        return "D"
    if row["BestValueExpReturns"] == row["ExpAwayReturns"]:
        return "A"

gambling_df["ValuePredResult"] = gambling_df.apply(lambda row: determine_bet(row),axis = 1)
gambling_df[gambling_df["season_gw"]>2].head()
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 20    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 21    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 22    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 23    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 24    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
#
#           AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 20  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 21  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 22  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 23  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 24  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
#
#     BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 20            5.75            9.50  Bet365         0.75188        0.173913
# ...

# %%
#calculate value of predictions

gambling_df["ValuePredCorrect"] = np.where(gambling_df["Result"]==gambling_df["ValuePredResult"],1,0)
gambling_df["ValuePredReturns"] = np.where(gambling_df["ValuePredCorrect"]==1,
                                           gambling_df["ResultReturns"],gambling_df["Stake"]*-1)
gambling_df[gambling_df["season_gw"]>2].head()
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 20    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 21    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 22    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 23    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 24    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
#
#           AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 20  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 21  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 22  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 23  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 24  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
#
#     BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 20            5.75            9.50  Bet365         0.75188        0.173913
# ...

# %%
#output csv
gambling_df.to_csv(data_folder+"/GamblingDataset.csv")

# %% [markdown]
# ## Compare betting results across leagues and methods
# We will take a sample of one bookie to make comparison easier

# %%
qa_df = gambling_df[(gambling_df["bookie"]=="Bet365") &
                   (gambling_df["BestValueExpReturns"]>0)].dropna().copy()
qa_df.head()
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 20    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 21    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 22    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 23    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 40    EPL  2016/17  01/01/17  Arsenal vs Crystal Palace  Arsenal
#
#           AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 20  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 21  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 22  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 23  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 40  Crystal Palace   2.0   0.0   H   1.0   0.0   H            1.29
#
#     BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 20            5.75             9.5  Bet365        0.751880        0.173913
# ...

# %%
for i in qa_df.league.unique():
    for j in qa_df[qa_df["league"]==i].season.unique():
        bets_df = qa_df[(qa_df["league"]==i) &
                        (qa_df["season"]==j)].dropna().copy()
        with pd.option_context('expand_frame_repr', False):
            print(bets_df.groupby(["league","season","AverageMethod"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                                                           ,ModelAcc=("PredCorrect","mean")
                                                                           ,ValueAcc=("ValuePredCorrect","mean")
                                                                           ,ValueReturns=("ValuePredReturns","sum")
                                                                           ,ModelResultProb=("FinalResultProb","mean")
                                                                           ,Counts=("fixture","nunique")).reset_index().head())
# Out:
#   league   season                AverageMethod  BookieAcc  ModelAcc  ValueAcc  ValueReturns  ModelResultProb  Counts
# 0    EPL  2015/16                 EMA No reset   0.470423  0.456338  0.304225          26.2        38.211986     355
# 1    EPL  2015/16             EMA Season reset   0.473088  0.475921  0.320113          16.7        38.751002     353
# 2    EPL  2015/16      Moving Average No reset   0.473088  0.439093  0.291785          37.6        37.897706     353
# 3    EPL  2015/16  Moving Average Season reset   0.476744  0.462209  0.322674          14.4        38.645955     344
#   league   season                AverageMethod  BookieAcc  ModelAcc  ValueAcc  ValueReturns  ModelResultProb  Counts
# 0    EPL  2016/17                 EMA No reset   0.605042  0.563025  0.268908       -323.20        42.766627     357
# 1    EPL  2016/17             EMA Season reset   0.609827  0.572254  0.361272        -91.75        43.986913     346
# ...

# %% [markdown]
# ### Analysis
# Initial results are not very positive. The model rarely outperforms the bookies in terms of accuracy. There are some fairly heavy losses. However for the premier league it does seem to be profitable and recently things are getting better.
#
# Let's restructure these summaries slightly to see if it helps draw any insight

# %%
qa_df.groupby(["league","AverageMethod"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                                                           ,ModelAcc=("PredCorrect","mean")
                                                                           ,ValueAcc=("ValuePredCorrect","mean")
                                                                           ,ValueReturns=("ValuePredReturns","sum")
                                                                           ,ModelResultProb=("FinalResultProb","mean")
                                                                           ,Counts=("fixture","nunique")).reset_index()
# Out:
#         league                AverageMethod  BookieAcc  ModelAcc  ValueAcc  \
# 0   Bundesliga                 EMA No reset   0.519627  0.493014  0.302728
# 1   Bundesliga             EMA Season reset   0.511186  0.486780  0.329492
# 2   Bundesliga      Moving Average No reset   0.514550  0.489418  0.283730
# 3   Bundesliga  Moving Average Season reset   0.520678  0.498305  0.335593
# 4          EPL                 EMA No reset   0.546185  0.527610  0.286647
# 5          EPL             EMA Season reset   0.546843  0.528513  0.314155
# 6          EPL      Moving Average No reset   0.544724  0.522613  0.300000
# 7          EPL  Moving Average Season reset   0.553268  0.529079  0.314977
# 8      La Liga                 EMA No reset   0.551630  0.529891  0.258696
# 9      La Liga             EMA Season reset   0.546291  0.515972  0.283162
# 10     La Liga      Moving Average No reset   0.548144  0.525551  0.268962
# ...

# %%
qa_df.groupby(["season","AverageMethod"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                                                           ,ModelAcc=("PredCorrect","mean")
                                                                           ,ValueAcc=("ValuePredCorrect","mean")
                                                                           ,ValueReturns=("ValuePredReturns","sum")
                                                                           ,ModelResultProb=("FinalResultProb","mean")
                                                                           ,Counts=("fixture","nunique")).reset_index()
# Out:
#      season                AverageMethod  BookieAcc  ModelAcc  ValueAcc  \
# 0   2014/15                 EMA No reset   0.521438  0.503153  0.302648
# 1   2014/15             EMA Season reset   0.521438  0.503153  0.302648
# 2   2014/15      Moving Average No reset   0.534221  0.515209  0.307351
# 3   2014/15  Moving Average Season reset   0.534221  0.515209  0.307351
# 4   2015/16                 EMA No reset   0.518987  0.500000  0.292405
# 5   2015/16             EMA Season reset   0.511292  0.486826  0.318068
# 6   2015/16      Moving Average No reset   0.512821  0.486554  0.287680
# 7   2015/16  Moving Average Season reset   0.510490  0.482517  0.320407
# 8   2016/17                 EMA No reset   0.571779  0.543558  0.304908
# 9   2016/17             EMA Season reset   0.570006  0.539515  0.345364
# 10  2016/17      Moving Average No reset   0.570815  0.539546  0.302269
# 11  2016/17  Moving Average Season reset   0.574858  0.538850  0.343020
# ...

# %% [markdown]
# Let's try a pivot table to see if we can see any trends more clearly

# %%
pd.pivot_table(qa_df.groupby(["season","league","AverageMethod"]).agg(BookieAcc=("BookiePredCorrect","mean")
                                                                           ,ModelAcc=("PredCorrect","mean")
                                                                           ,ValueAcc=("ValuePredCorrect","mean")
                                                                           ,ValueReturns=("ValuePredReturns","sum")
                                                                           ,ModelResultProb=("FinalResultProb","mean")
                                                                           ,Counts=("fixture","nunique")).reset_index()
              ,values="ValueReturns",index=["league","AverageMethod"],columns =["season"],aggfunc ="sum",margins = True)
# Out:
# season                                  2014/15  2015/16  2016/17  2017/18  \
# league     AverageMethod
# Bundesliga EMA No reset                  -73.50   -95.60    -6.35  -175.25
#            EMA Season reset              -73.50   -42.10   -26.35   -89.85
#            Moving Average No reset       -73.80   -61.00  -113.90  -221.90
#            Moving Average Season reset   -73.80    -4.75   -27.05    -6.40
# EPL        EMA No reset                   28.45    26.20  -323.20   -26.70
#            EMA Season reset               28.45    16.70   -91.75  -183.95
#            Moving Average No reset        78.20    37.60  -267.95    33.95
#            Moving Average Season reset    78.20    14.40  -196.55  -115.15
# La Liga    EMA No reset                 -250.95  -339.40  -329.70   -53.65
#            EMA Season reset             -250.95  -262.30  -296.30   -91.45
#            Moving Average No reset      -278.45  -314.45  -296.15   -58.50
# ...

# %% [markdown]
# The above layout shows things more clearly. Overall the signs aren't great, but the latest season is quite profitable and generally we do better in the Premier League. La Liga is not good for us though

# %% [markdown]
# Let's see if we can calculate profit across different strength of value bins using our expected profit metric

# %%
bins = pd.IntervalIndex.from_tuples([(0,0.5), (0.5001, 1.5), (1.5001, 3),(3.001,5),(5.001,10),(10.001,100)])
qa_df['bet_bin'] = pd.cut(qa_df['BestValueExpReturns'],bins)

qa_df.groupby(["AverageMethod","league","season","bet_bin"]).agg({"ValuePredCorrect":"mean"
                                                                         ,"ValuePredReturns":"sum"
                                                                          ,"fixture":"nunique"}).reset_index().head(60)
# Out:
#    AverageMethod      league   season          bet_bin  ValuePredCorrect  \
# 0   EMA No reset  Bundesliga  2014/15       (0.0, 0.5]          0.351064
# 1   EMA No reset  Bundesliga  2014/15    (0.5001, 1.5]          0.333333
# 2   EMA No reset  Bundesliga  2014/15    (1.5001, 3.0]          0.176471
# 3   EMA No reset  Bundesliga  2014/15     (3.001, 5.0]          0.272727
# 4   EMA No reset  Bundesliga  2014/15    (5.001, 10.0]          0.375000
# 5   EMA No reset  Bundesliga  2014/15  (10.001, 100.0]          0.000000
# 6   EMA No reset  Bundesliga  2015/16       (0.0, 0.5]          0.428571
# 7   EMA No reset  Bundesliga  2015/16    (0.5001, 1.5]          0.265487
# 8   EMA No reset  Bundesliga  2015/16    (1.5001, 3.0]          0.222222
# 9   EMA No reset  Bundesliga  2015/16     (3.001, 5.0]          0.100000
# 10  EMA No reset  Bundesliga  2015/16    (5.001, 10.0]          0.000000
# 11  EMA No reset  Bundesliga  2015/16  (10.001, 100.0]               NaN
# ...

# %%
pd.pivot_table(qa_df,values="ValuePredReturns",index=["league","AverageMethod"],columns =["bet_bin"],aggfunc ="sum",margins = True)
# Out:
# bet_bin                                 (0.0, 0.5]  (0.5001, 1.5]  \
# league     AverageMethod
# Bundesliga EMA No reset                      18.50        -738.25
#            EMA Season reset                   3.05        -349.80
#            Moving Average No reset         -363.55        -335.60
#            Moving Average Season reset      -73.90        -130.65
# EPL        EMA No reset                    -430.75          12.55
#            EMA Season reset                -169.55        -389.30
#            Moving Average No reset           28.90          75.30
#            Moving Average Season reset     -208.05        -148.55
# La Liga    EMA No reset                    -365.10        -372.40
#            EMA Season reset                 -73.70        -536.35
#            Moving Average No reset         -342.35        -152.65
#            Moving Average Season reset     -365.55        -121.65
# Ligue 1    EMA No reset                    -156.80        -375.80
# ...

# %%
pd.pivot_table(qa_df[qa_df["league"]=="EPL"],values="ValuePredReturns",index=["league","AverageMethod","season"]
               ,columns =["bet_bin"],aggfunc =["sum","count"],margins = True)
# Out:
#                                                   sum                \
# bet_bin                                    (0.0, 0.5] (0.5001, 1.5]
# league AverageMethod               season
# EPL    EMA No reset                2014/15    -121.50        -38.65
#                                    2015/16     -41.90         -3.90
#                                    2016/17    -121.05        -31.65
#                                    2017/18     -89.70         50.05
#                                    2018/19     -33.00        119.60
#                                    2019/20     -23.60        -82.90
#        EMA Season reset            2014/15    -121.50        -38.65
#                                    2015/16    -107.40        -27.00
#                                    2016/17      80.10       -131.10
#                                    2017/18     -52.10       -144.65
#                                    2018/19      -9.70         59.15
# ...

# %%
#sns.xlim(0, 20)
sns.distplot(qa_df["BestValueExpReturns"]).set(xlim=(0,20))
# Out:
# [(0, 20)]

# %% [markdown]
# ## Converting Expected Profit into a more standard metric
# Expected profit can be influenced by the size of stake, so let's try and create another metric

# %%
#qa_df.info()
qa_df["BetIndexHome"] = (qa_df["HomeProb"]/100)/qa_df["BookieHomeProb"]
qa_df["BetIndexDraw"] = (qa_df["DrawProb"]/100)/qa_df["BookieDrawProb"]
qa_df["BetIndexAway"] = (qa_df["AwayProb"]/100)/qa_df["BookieAwayProb"]

qa_df.head()

qa_df["BestValueIndex"]= qa_df[["BetIndexHome","BetIndexDraw","BetIndexAway"]].max(axis=1)


def determine_bet(row):
    #if np.isnan(row["PredResult"])==False:
    if row["BestValueIndex"] == row["BetIndexHome"]:
        return "H"
    if row["BestValueIndex"] == row["BetIndexDraw"]:
        return "D"
    if row["BestValueIndex"] == row["BetIndexAway"]:
        return "A"
    
qa_df["IndexPredResult"] = qa_df.apply(lambda row: determine_bet(row),axis = 1)
qa_df[qa_df["season_gw"]>2].head()
# Out:
#    league   season      Date                    fixture HomeTeam  \
# 20    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 21    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 22    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 23    EPL  2015/16  17/04/16  Arsenal vs Crystal Palace  Arsenal
# 40    EPL  2016/17  01/01/17  Arsenal vs Crystal Palace  Arsenal
#
#           AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  \
# 20  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 21  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 22  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 23  Crystal Palace   1.0   1.0   D   1.0   0.0   H            1.33
# 40  Crystal Palace   2.0   0.0   H   1.0   0.0   H            1.29
#
#     BookieDrawOdds  BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  \
# 20            5.75             9.5  Bet365        0.751880        0.173913
# ...

# %% [markdown]
# ### Checking the distribution of the best value index

# %%
sns.distplot(qa_df["BestValueIndex"]).set(xlim=(0,5))
# Out:
# [(0, 5)]

# %%
sns.scatterplot(x="BestValueIndex",y="BestValueExpReturns",data = qa_df)

# %% [markdown]
# ## We can find the right cut offs for our best value index comparing the best value bet

# %%
pd.pivot_table(qa_df[qa_df["league"]=="EPL"],values="BestValueIndex",index=["league","AverageMethod","season"]
               ,columns =["bet_bin"],aggfunc =["min"],margins = False)
# Out:
#                                                   min                \
# bet_bin                                    (0.0, 0.5] (0.5001, 1.5]
# league AverageMethod               season
# EPL    EMA No reset                2014/15   1.000352      1.101259
#                                    2015/16   1.002789      1.100292
#                                    2016/17   1.000553      1.100879
#                                    2017/18   1.000635      1.100434
#                                    2018/19   1.000743      1.101246
#                                    2019/20   1.001367      1.100178
#        EMA Season reset            2014/15   1.000352      1.101259
#                                    2015/16   1.000472      1.100895
#                                    2016/17   1.000649      1.100388
#                                    2017/18   1.000646      1.100641
#                                    2018/19   1.001050      1.100691
# ...

# %%
index_bins = pd.IntervalIndex.from_tuples([(1,1.1), (1.101, 1.3), (1.3001, 1.6),(1.6001,2),(2.001,3),(3.001,10)])
qa_df['index_bin'] = pd.cut(qa_df['BestValueIndex'],index_bins)

# %%
pd.pivot_table(qa_df[qa_df["league"]=="EPL"],values="ValuePredReturns",index=["league","AverageMethod","season"]
               ,columns =["index_bin"],aggfunc =["sum","count"],margins = True)
# Out:
#                                                   sum               \
# index_bin                                  (1.0, 1.1] (1.101, 1.3]
# league AverageMethod               season
# EPL    EMA No reset                2014/15    -121.50       -38.65
#                                    2015/16     -41.90         3.90
#                                    2016/17    -121.05       -26.65
#                                    2017/18     -89.70        55.05
#                                    2018/19     -33.00       119.60
#                                    2019/20     -23.60       -77.90
#        EMA Season reset            2014/15    -121.50       -38.65
#                                    2015/16    -107.40       -22.00
#                                    2016/17      80.10      -142.10
#                                    2017/18     -52.10      -139.65
#                                    2018/19      -9.70        64.15
# ...

# %% [markdown]
# ## Analysis
# Broadly speaking the 1.3 to 1.6 Betting Index mark seems to be the sweet spot for Premier League Predictions. <br>
# This is mostly down to good performance over the current and previous season

# %%
graph_df = qa_df[(qa_df["league"]=="EPL")
                #(qa_df["season"]=="2018/19")
                ]
g = sns.FacetGrid(graph_df, col = "season_gw", hue = "AverageMethod")
g.map(plt.plot, "season_gw", "ValuePredReturns")

#sns.lineplot(x="season_gw",y="ValuePredReturns", data =graph_df,hue = "AverageMethod",ci = None)

# %%
graph_df = qa_df[(qa_df["league"]=="EPL")
                #(qa_df["season"]=="2018/19")
                ].groupby(["season","AverageMethod","season_gw"])["ValuePredReturns"].agg("sum").reset_index()
graph_df.head()
graph_df["Cumulative"] = graph_df.groupby(["season","AverageMethod"])["ValuePredReturns"].cumsum()
graph_df.head()
# Out:
#     season AverageMethod  season_gw  ValuePredReturns  Cumulative
# 0  2014/15  EMA No reset          3             93.25       93.25
# 1  2014/15  EMA No reset          4              5.00       98.25
# 2  2014/15  EMA No reset          5             68.00      166.25
# 3  2014/15  EMA No reset          6            -42.15      124.10
# 4  2014/15  EMA No reset          7            -32.10       92.00

# %%
# Plot the lines on two facets

sns.relplot(x="season_gw", y="Cumulative",
            hue="AverageMethod", row="season",ci = None,
            height=3, aspect=3, facet_kws=dict(sharex=False),
            kind="line", legend="full", data=graph_df)

# %%
graph_df2 = qa_df[(qa_df["league"]=="EPL") &
                (qa_df["BestValueIndex"]>1.3)
                ].groupby(["season","AverageMethod","season_gw"])["ValuePredReturns"].agg("sum").reset_index()
graph_df2.head()
graph_df2["Cumulative"] = graph_df2.groupby(["season","AverageMethod"])["ValuePredReturns"].cumsum()
graph_df2.head()
# Out:
#     season AverageMethod  season_gw  ValuePredReturns  Cumulative
# 0  2014/15  EMA No reset          3             76.00       76.00
# 1  2014/15  EMA No reset          4             20.00       96.00
# 2  2014/15  EMA No reset          5             83.00      179.00
# 3  2014/15  EMA No reset          6            -25.00      154.00
# 4  2014/15  EMA No reset          7            -30.45      123.55

# %%
sns.relplot(x="season_gw", y="Cumulative",
            hue="AverageMethod", row="season",ci = None,
            height=3, aspect=3, facet_kws=dict(sharex=False),
            kind="line", legend="full", data=graph_df2)

# %% [markdown]
# # QA null fixtures

# %%
qa = qa_df[(qa_df["league"]=="EPL") &
      (qa_df["season"]=="2015/16") &
      (qa_df["AverageMethod"].isin(["EMA Season reset","Moving Average Season reset"]))
     ]
print(qa.groupby(["season_gw","AverageMethod"])["fixture"].nunique())
qa[qa["season_gw"].isin([37,38])].sort_values(["season_gw","fixture"])[["fixture","AverageMethod","season_gw"]]
# Out:
# season_gw  AverageMethod
# 3          EMA Season reset               10
#            Moving Average Season reset    10
# 4          EMA Season reset               10
#            Moving Average Season reset    10
# 5          EMA Season reset               10
#                                           ..
# 36         Moving Average Season reset    10
# 37         EMA Season reset                9
#            Moving Average Season reset    10
# 38         EMA Season reset               10
#            Moving Average Season reset     9
# Name: fixture, Length: 72, dtype: int64
#                                    fixture                AverageMethod  \
# 32942  Bournemouth vs West Bromwich Albion             EMA Season reset
# 32943  Bournemouth vs West Bromwich Albion  Moving Average Season reset
# 20422                 Leicester vs Everton             EMA Season reset
# 20423                 Leicester vs Everton  Moving Average Season reset
# ...

# %%
qa[qa["fixture"]=="Watford vs Sunderland"]
# Out:
#       league   season      Date                fixture HomeTeam    AwayTeam  \
# 31562    EPL  2015/16  15/05/16  Watford vs Sunderland  Watford  Sunderland
#
#        FTHG  FTAG FTR  HTHG  HTAG HTR  BookieHomeOdds  BookieDrawOdds  \
# 31562   2.0   2.0   D   0.0   1.0   A            2.05            3.75
#
#        BookieAwayOdds  bookie  BookieHomeProb  BookieDrawProb  BookieAwayProb  \
# 31562             3.7  Bet365        0.487805        0.266667         0.27027
#
#        BookieMargin BookiePredResult  BookiePredResultProb  \
# 31562      2.474181                H              0.487805
#
#        BookieFinalResultProb  BookiePredCorrect  season_gw  ...   Team_Away  \
# 31562               0.266667                  0         38  ...  Sunderland
#
#       Result     AverageMethod   HomeProb   DrawProb   AwayProb  PredResult  \
# 31562      D  EMA Season reset  37.294633  26.046079  36.659002           H
#
#       PredScore PredScoreProb  PredResultScore PredResultScoreProb  \
# ...

# %%
qa_team = pd.read_csv(data_folder+"/xg_predictions.csv")
qa_team = qa_team[(qa_team["season"]=="2015/16") &
                  (qa_team["fixture"]=="Watford vs Sunderland")
                 ]
qa_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 10372 to 10375
# Data columns (total 39 columns):
# league                    4 non-null object
# season                    4 non-null object
# fixture                   4 non-null object
# season_gw                 4 non-null int64
# Team_Home                 4 non-null object
# Team_Away                 4 non-null object
# homegoals                 4 non-null float64
# awaygoals                 4 non-null float64
# Result                    4 non-null object
# AverageMethod             4 non-null object
# xG_av_Home                4 non-null float64
# xGA_av_Home               4 non-null float64
# AttStr_Home               4 non-null float64
# DefStr_Home               4 non-null float64
# xG_av_Away                4 non-null float64
# xGA_av_Away               4 non-null float64
# AttStr_Away               4 non-null float64
# DefStr_Away               4 non-null float64
# SeasonHG                  4 non-null float64
# ...
